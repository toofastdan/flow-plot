# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

# %%
events = pd.read_csv("C:/Users/ToofastDan/flow-plot/flow-plot/FlowJo Sample CSV Files/export_mouse derived MSCs_BM adh Hx_005_Live_dead.csv")

# %%
print(events.head())
# Out:
#       FSC-A    SSC-A  APC-A :: CD90-2  APC-Cy7-A :: TER119-CD45  \
# 0  215321.0  94919.8          5144.02                   13245.5
# 1  124124.0  92434.7          5881.20                   14038.9
# 2  139390.0  61043.6          4543.72                   10906.3
# 3   69056.0  69948.8          2817.06                    6580.1
# 4   90276.1  37882.3          3340.80                    8482.5
#
#    AmCyan-A :: Live_dead  FITC-A :: GFP     PE-A  PE-Cy7-A :: CD29  \
# 0                1829.25        2003.82  1846.26           19688.0
# 1                1173.00        1040.52  1540.50           35284.1
# 2                1437.00        1813.50  2152.80           32793.5
# 3                1200.75        1320.54  1431.30           11370.8
# 4                1173.75        1300.26  1305.72           22287.7
#
#    Pacific Blue-A :: CD31  PerCP-Cy5-5-A :: CD105  Time
# 0                  576.00                 3019.38  50.1
# 1                  329.25                 4056.00  52.0
# 2                  570.75                 4595.76  52.0
# 3                  429.75                 1924.26  52.1
# 4                  466.50                 2337.66  52.7

# %%
print(events.dtypes)
# Out:
# FSC-A                       float64
# SSC-A                       float64
# APC-A :: CD90-2             float64
# APC-Cy7-A :: TER119-CD45    float64
# AmCyan-A :: Live_dead       float64
# FITC-A :: GFP               float64
# PE-A                        float64
# PE-Cy7-A :: CD29            float64
# Pacific Blue-A :: CD31      float64
# PerCP-Cy5-5-A :: CD105      float64
# Time                        float64
# dtype: object

# %%
sns.set(style="white")

# %%
f, ax = plt.subplots(figsize=(7,7))
ax = sns.scatterplot(x='FSC-A', y='SSC-A', data=events)
ax.set_title("FSC vs SSC")
plt.show()

# %%
f, ax = plt.subplots(figsize=(7,7))
x = 10**np.arrange(1,10)
y = x * 2

# %%
#f, ax = plt.subplots(figsize=(7,7))
#ax = sns.scatterplot(x='FSC-A', y="FSC-H", data=events)
#plt.show()

# %%
f, ax = plt.subplots(figsize=(7,7))

ax = sns.scatterplot(x='APC-Cy7-A :: TER119-CD45', y='Pacific Blue-A :: CD31', data=events)
ax.set_title("Ter119/CD45 vs CD31")

ax.set(xlim=(10,50000), ylim=(50,3000))
ax.set_xscale('log')
ax.set_yscale('log')

plt.show()

# %%
def change_width(ax, new_value):
    for patch in ax.patches:
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

# %%
#mybins = np.logspace(0, np.log(100), 100)

ax = sns.jointplot(x="APC-Cy7-A :: TER119-CD45", y="Pacific Blue-A :: CD31",
                  data=events, kind="reg",
                  xlim=(10,50000), ylim=(50,10000), height=7)

#ax.plot_marginals(sns.distplot, color='blue', bins=mybins)
#ax = ax.plot(sns.regplot, sns.distplot)

graph = ax.ax_joint
graph.set_xscale('log')
graph.set_yscale('log')
plt.show()
